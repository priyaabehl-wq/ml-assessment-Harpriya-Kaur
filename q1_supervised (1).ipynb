# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8cdbf6c9-e8e7-4854-a660-b150d21cf7ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8cdbf6c9-e8e7-4854-a660-b150d21cf7ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('q1_heart_disease.csv')
df.head()

# %%
# Shape
print("Shape:", df.shape)

# Data types
print("\nData Types:\n", df.dtypes)

# Missing values
print("\nMissing Values:\n", df.isnull().sum())

# %% [markdown]
# ### Data Inspection
#
# - The dataset contains multiple clinical features such as age, cholesterol, and heart rate.
# - The target variable is `heart_disease` (1 = disease present, 0 = absent).
# - The dataset shape and data types help in understanding feature structure.
# - Missing values (if any) need to be handled during preprocessing.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='heart_disease', data=df)
plt.title('Heart Disease Distribution')
plt.show()

# %% [markdown]
# ### Target Distribution
#
# - This plot shows the number of patients with and without heart disease.
# - If both classes are nearly equal, the dataset is balanced.
# - A balanced dataset helps models learn both classes effectively.

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Correlation Analysis
#
# - The heatmap shows relationships between variables.
# - Strong positive or negative correlations indicate important features.
# - Features like max_hr, oldpeak, or chest pain type may influence heart disease.

# %%
sns.countplot(x='chest_pain_type', hue='heart_disease', data=df)
plt.title('Chest Pain Type vs Heart Disease')
plt.show()

# %% [markdown]
# ### Feature Relationship
#
# - Chest pain type appears to be an important indicator.
# - Some categories show higher association with heart disease presence.

# %%
# Handle missing values
df.fillna(df.median(numeric_only=True), inplace=True)

# %% [markdown]
# ### Missing Value Handling
#
# - Median imputation is used as it is robust to outliers.
# - This is suitable for medical datasets.

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

X = df.drop('heart_disease', axis=1)
y = df['heart_disease']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, stratify=y, random_state=42
)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)
gb = GradientBoostingClassifier(random_state=42)

dt.fit(X_train, y_train)
rf.fit(X_train, y_train)
gb.fit(X_train, y_train)

# %%
from sklearn.metrics import confusion_matrix, classification_report

models = {
    "Decision Tree": dt,
    "Random Forest": rf,
    "Gradient Boosting": gb
}

for name, model in models.items():
    print(f"\n{name}")
    y_pred = model.predict(X_test)

    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))

# %% [markdown]
# ### 🏆 Final Model Comparison and Selection
#
# All three models were evaluated using Precision, Recall, and F1-score.
#
# - The Decision Tree model showed lower performance and higher misclassification, indicating overfitting.
# - Gradient Boosting performed better but still had slightly lower recall compared to the best model.
# - The Random Forest model achieved the best overall performance.
#
# **Justification:**
# - It has the highest F1-score, indicating a good balance between precision and recall.
# - It provides better recall for class 1 (heart disease), which is critical in medical diagnosis.
# - It produces fewer false negatives, reducing the risk of missing actual disease cases.
#
# Therefore, Random Forest is selected as the best-performing model for this task.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

param_grid = {

    'n_estimators': [50, 100],
    'max_depth': [3, 5, None]
}

grid = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid,
    cv=5,
    scoring='f1'
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)

# %%
best_model = grid.best_estimator_

from sklearn.metrics import classification_report, confusion_matrix

y_pred = best_model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# ### 🔧 Hyperparameter Tuning
#
# GridSearchCV was used to tune the Random Forest model.
#
# **Best Parameters:**
# (Write what you got here)
#
# **Interpretation:**
# - The tuned model was compared with the baseline model.
# - If performance improved, it indicates better generalization.
# - If performance remained similar, it suggests the default model was already well-optimized.
#
# Overall, hyperparameter tuning helps in improving model performance and reducing overfitting.
